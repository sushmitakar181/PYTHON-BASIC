# %% [markdown]
# Q1. Write a Python program to print "Hello, World!_

# %%
print("hello, world")
# Out:
# hello, world

# %% [markdown]
# Q2. Write a Python program that displays your name and age.

# %%
name=("Sushmita Chakraborty")
age=("30")
print(name,age)
# Out:
# Sushmita Chakraborty 30

# %% [markdown]
# Q3. Write code to print all the pre-defined keywords in Python using the keyword library

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# Q4. Write a program that checks if a given word is a Python keyword

# %%
import keyword
s=input("entre any word")
import keyword
s=input("entre any word")
if keyword.iskeyword(s):
  print("your entered word is keyword")
else:
  print("your entered word is not a keyword")

# %% [markdown]
# Q5.Create a list and tuple in Python, and demonstrate how attempting to change an element works differently
# for each

# %%
num=[3, 4, 6, 8, 4, 2, 9]
num2= (1, 4, 5, 8)
print("Elements in list", len(num))
print("Elements in tuple", len(num 2))
